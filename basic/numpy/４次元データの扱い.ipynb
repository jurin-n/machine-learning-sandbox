# %%
import numpy as np

# %% [markdown]
# # チャンネル2、高さ40、横幅20のデータを10個作成

# %%
x = np.random.rand(10,2,40,20)

# %% [markdown]
# # 形状を確認

# %%
N, C, H, W = x.shape
print('N=' + str(N))
print('C=' + str(C))
print('H=' + str(H))
print('W=' + str(W))

# %% [markdown]
# # データを確認

# %%
x

# %% [markdown]
# # ひとつ目のデータにアクセス

# %%
# 形状
x[0].shape

# %%
# データ
x[0]

# %% [markdown]
# # ひとつ目のデータの１チャンネル目のデータにアクセス

# %%
x[0, 0] # もしくは、x[0][0]
